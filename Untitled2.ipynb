# %%
import pandas as pd
L=["orange","pears","cherries","apple"]
M=[12,20,1,100]
S=pd.Series(M)
K=pd.Series(M,index=L)
print(S)
print(K)
# Out:
# 0     12
# 1     20
# 2      1
# 3    100
# dtype: int64
# orange       12
# pears        20
# cherries      1
# apple       100
# dtype: int64

# %%
import numpy as np
import pandas as pd
my_numpy_array=np.random.randint(2,5, size=(3,4))
df=pd.DataFrame(my_numpy_array, columns=["a","b","c","d"])
print(df)
# Out:
#    a  b  c  d
# 0  2  4  3  2
# 1  2  4  2  2
# 2  3  2  3  2

# %%
df=pd.read_csv("SuperStoreOrders.csv")

df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
new_data=df.copy().drop("segment",axis=1)
new_data['quantity'].describe()
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name             state        country  market   region  \
# 0       Toby Braunhardt       Constantine        Algeria  Africa   Africa
# 1           Joseph Holt   New South Wales      Australia    APAC  Oceania
# ...

# %%
new_data['quantity'].describe()
# Out:
# count    51290.000000
# mean         3.476545
# std          2.278766
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max         14.000000
# Name: quantity, dtype: float64

# %%
dict={"Name":["John","Mery","Ali","Ahmed","Sarah","Asma","Hakim","Rachid","Fatima"],"Last Name":["Moussaoui","Eric","Benani","Rifki","Youssfi","filali","raoui","bahi","Rifki"],"Age":[18,25,30,40,12,17,25,30,45],"Job":["Engineer","Teacher","Doctor","Journalist","Data scientist","Freelancer","Teacher","Doctor","Freelancer"],"salary":[9000,8000,10000,5000,20000,50000,9500,30000,45000],"ID":["J0","M1","A2","A3","S4","A5","H6","R7","F8"]}
data=pd.DataFrame(dict)
data.to_csv('donnee.csv')
new_data=pd.read_csv('donnee.csv')
new_data=new_data.drop("Unnamed: 0",axis=1)
new_data
# Out:
#      Name  Last Name  Age             Job  salary  ID
# 0    John  Moussaoui   18        Engineer    9000  J0
# 1    Mery       Eric   25         Teacher    8000  M1
# 2     Ali     Benani   30          Doctor   10000  A2
# 3   Ahmed      Rifki   40      Journalist    5000  A3
# 4   Sarah    Youssfi   12  Data scientist   20000  S4
# 5    Asma     filali   17      Freelancer   50000  A5
# 6   Hakim      raoui   25         Teacher    9500  H6
# 7  Rachid       bahi   30          Doctor   30000  R7
# 8  Fatima      Rifki   45      Freelancer   45000  F8

# %%
new_data=new_data.set_index('ID')
new_data
# Out:
#       Name  Last Name  Age             Job  salary
# ID
# J0    John  Moussaoui   18        Engineer    9000
# M1    Mery       Eric   25         Teacher    8000
# A2     Ali     Benani   30          Doctor   10000
# A3   Ahmed      Rifki   40      Journalist    5000
# S4   Sarah    Youssfi   12  Data scientist   20000
# A5    Asma     filali   17      Freelancer   50000
# H6   Hakim      raoui   25         Teacher    9500
# R7  Rachid       bahi   30          Doctor   30000
# F8  Fatima      Rifki   45      Freelancer   45000

# %%
new_data['full Name']=new_data['Name']+ " "+ new_data['Last Name']
new_data
# Out:
#       Name  Last Name  Age             Job  salary       full Name
# ID
# J0    John  Moussaoui   18        Engineer    9000  John Moussaoui
# M1    Mery       Eric   25         Teacher    8000       Mery Eric
# A2     Ali     Benani   30          Doctor   10000      Ali Benani
# A3   Ahmed      Rifki   40      Journalist    5000     Ahmed Rifki
# S4   Sarah    Youssfi   12  Data scientist   20000   Sarah Youssfi
# A5    Asma     filali   17      Freelancer   50000     Asma filali
# H6   Hakim      raoui   25         Teacher    9500     Hakim raoui
# R7  Rachid       bahi   30          Doctor   30000     Rachid bahi
# F8  Fatima      Rifki   45      Freelancer   45000    Fatima Rifki

# %%
new_data=new_data.drop(["Name","Last Name"],axis=1)
new_data
# Out:
#     Age             Job  salary       full Name
# ID
# J0   18        Engineer    9000  John Moussaoui
# M1   25         Teacher    8000       Mery Eric
# A2   30          Doctor   10000      Ali Benani
# A3   40      Journalist    5000     Ahmed Rifki
# S4   12  Data scientist   20000   Sarah Youssfi
# A5   17      Freelancer   50000     Asma filali
# H6   25         Teacher    9500     Hakim raoui
# R7   30          Doctor   30000     Rachid bahi
# F8   45      Freelancer   45000    Fatima Rifki

# %%
data1=new_data.loc[new_data.salary>=10000,'Name':'salary']
data1
# Out:
#       Name  Age             Job  salary
# ID
# A2     Ali   30          Doctor   10000
# S4   Sarah   12  Data scientist   20000
# A5    Asma   17      Freelancer   50000
# R7  Rachid   30          Doctor   30000
# F8  Fatima   45      freelancer   45000

# %%
data2=new_data.iloc[2:,:2]
data2
# Out:
#       Name  Age
# ID
# A2     Ali   30
# A3   Ahmed   40
# S4   Sarah   12
# A5    Asma   17
# H6   Hakim   25
# R7  Rachid   30
# F8  Fatima   45

# %%
data3=new_data.loc[(new_data.Job=='Freelancer') & (new_data.salary>=50000),'Job':'full Name']
data3
# Out:
#            Job  salary    full Name
# ID
# A5  Freelancer   50000  Asma filali

# %%
data4=new_data[new_data['salary']>=45000]
data4
# Out:
#         Age         Job  salary  ID
# Name
# Asma     17  Freelancer   50000  A5
# Fatima   45  Freelancer   45000  F8

# %%
# Out:
#       Name  Age         Job  salary
# ID
# A5    Asma   17  Freelancer   50000
# F8  Fatima   45  Freelancer   45000

# %%
import pandas as pd
df=pd.read_csv("SuperStoreOrders.csv",index_col='order_id')
df.head(8)
# Out:
#                 order_date ship_date       ship_mode    customer_name  \
# order_id
# AG-2011-2040      1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# IN-2011-47883     1/1/2011  8/1/2011  Standard Class      Joseph Holt
# HU-2011-1220      1/1/2011  5/1/2011    Second Class    Annie Thurman
# IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# IN-2011-47883     1/1/2011  8/1/2011  Standard Class      Joseph Holt
# IN-2011-47883     1/1/2011  8/1/2011  Standard Class      Joseph Holt
# CA-2011-1510      2/1/2011  6/1/2011  Standard Class  Magdelene Morse
# IN-2011-79397     3/1/2011  3/1/2011        Same Day      Kean Nguyen
#
#                      segment            state    country  market   region  \
# order_id
# AG-2011-2040        Consumer      Constantine    Algeria  Africa   Africa
# IN-2011-47883       Consumer  New South Wales  Australia    APAC  Oceania
# HU-2011-1220        Consumer         Budapest    Hungary    EMEA     EMEA
# ...

# %%
new_df=df.iloc[1:7,1:5]
new_df
# Out:
#   order_date ship_date       ship_mode    customer_name
# 1   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 5   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 6   2/1/2011  6/1/2011  Standard Class  Magdelene Morse

# %%
df1=df.loc['AG-2011-2040':'IN-2011-79397',['order_date','segment']]
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3452\4199098374.py in <module>
# ----> 1 df1=df.loc['AG-2011-2040':'IN-2011-79397',['order_date','segment']]
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# -> 1149         return self._getitem_tuple_same_dim(tup)
#    1150
#    1151     def _get_label(self, label, axis: int):
#
# ...
